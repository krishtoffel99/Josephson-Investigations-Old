# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import kwant
import functions as func
from types import SimpleNamespace
import numpy as np
# Out:
# /Users/krishnanganesh/anaconda3/lib/python3.8/site-packages/kwant/solvers/default.py:16: RuntimeWarning: MUMPS is not available, SciPy built-in solver will be used as a fallback. Performance can be very poor in this case.
#   warnings.warn("MUMPS is not available, "

# %% [markdown]
# ## Kwant Simulations

# %%
syst = func.make_system(a=1, W=100, L=100, dL=0, Wb=10)
kwant.plot(syst);

# %%
par = SimpleNamespace(t=1, mu=1.01, U0=0, flux=0.5)
smatrix = kwant.smatrix(syst, energy=0, args=[par])
supercurrent = func.supercurrent_tight_binding(smatrix=smatrix, phi=np.pi/2, Delta=0.1)
# Out:
# /var/folders/q7/mt24cx7d41b3712vq5fcskd80000gn/T/ipykernel_57071/3164110443.py:2: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   smatrix = kwant.smatrix(syst, energy=0, args=[par])
# /Users/krishnanganesh/anaconda3/lib/python3.8/site-packages/kwant/solvers/common.py:162: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   lhs, norb = syst.hamiltonian_submatrix(args, sparse=True,
# /Users/krishnanganesh/anaconda3/lib/python3.8/site-packages/kwant/solvers/common.py:191: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   prop, stab = lead.modes(energy, args, params=params)
# /Users/krishnanganesh/anaconda3/lib/python3.8/site-packages/kwant/system.py:305: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   ham = self.cell_hamiltonian(args, params=params)
# /Users/krishnanganesh/anaconda3/lib/python3.8/site-packages/kwant/system.py:273: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   return self.hamiltonian_submatrix(args, cell_sites, cell_sites,
# /Users/krishnanganesh/anaconda3/lib/python3.8/site-packages/kwant/system.py:306: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   hop = self.inter_cell_hopping(args, params=params)
# /Users/krishnanganesh/anaconda3/lib/python3.8/site-packages/kwant/system.py:285: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   return self.hamiltonian_submatrix(args, cell_sites, interface_sites,
# /Users/krishnanganesh/anaconda3/lib/python3.8/site-packages/kwant/system.py:307: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   symmetries = self.discrete_symmetry(args, params=params)
# /Users/krishnanganesh/anaconda3/lib/python3.8/site-packages/kwant/builder.py:1944: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   return None if op is None else op.tocoo(args, params=params)

# %%
eigvals, eigvecs = func.andreev_states(syst=syst, par=par, phi=np.pi/2, Delta=0.1)
kwant_wf = kwant.wave_function(syst, energy=0, args=[par])
Andreev_bs = func.andreev_wf(eigvecs, kwant_wf)
# Out:
# /Users/krishnanganesh/Desktop/Josephson Investigations/Josephson effect and Supercurrents/Reproducing Paper/hourglass-jj-publication-code/functions.py:172: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   s = kwant.smatrix(syst, energy=0, args=[par])
# /var/folders/q7/mt24cx7d41b3712vq5fcskd80000gn/T/ipykernel_57071/747502247.py:2: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   kwant_wf = kwant.wave_function(syst, energy=0, args=[par])

# %%
current = func.intensity(syst=syst, psi=Andreev_bs, par=par)
# Out:
# /Users/krishnanganesh/Desktop/Josephson Investigations/Josephson effect and Supercurrents/Reproducing Paper/hourglass-jj-publication-code/functions.py:230: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   return sum(I_operator(psi_i, args=[par]) for psi_i in psi)

# %%
kwant.plotter.current(syst, current);
# Out:
# /var/folders/q7/mt24cx7d41b3712vq5fcskd80000gn/T/ipykernel_57071/647436197.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   kwant.plotter.current(syst, current);

# %% [markdown]
# ## Quasiclassical Calculations

# %%
par = SimpleNamespace(W=500, L=500, dL=0, Wb=20, phi=np.pi/2, lm=1e10)

supercurrent_quasiclassic = func.quasiclassical_supercurrent_asymmetric(par)[0]

# %%
supercurrent_quasiclassic

# %%
par1 = SimpleNamespace(W=500, L=500, Wb=20, phi=np.pi/2, lm=202, k1=1, k2=1.5)
supercurreny_tunable = func.quasiclassical_supercurrent_tunable_densities(par1)[0]

# %%
supercurreny_tunable
